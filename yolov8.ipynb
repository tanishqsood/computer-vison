# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishqsood/computer-vison/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed May 15 08:43:52 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.9/756.9 kB 7.4 MB/s eta 0:00:00

# %%
# !yolo detect predict model=yolov8m.pt source="/content/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.mp4"
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 349MB/s]
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/600) /content/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.mp4: 384x640 4 cars, 83.6ms
# video 1/1 (frame 2/600) /content/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.mp4: 384x640 4 cars, 25.4ms
# video 1/1 (frame 3/600) /content/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.mp4: 384x640 5 cars, 25.5ms
# video 1/1 (frame 4/600) /content/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.mp4: 384x640 4 cars, 27.1ms
# video 1/1 (frame 5/600) /content/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.mp4: 384x640 3 persons, 4 cars, 25.4ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict/MFK5_D025185_20201221_045958_PDX-X650RC02-A06006-V120803F_VIDEO_000059.avi"} -vcodec libx264 {"MFK5.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !yolo detect predict model=yolov8m.pt source="/content/MFK5_D025185_20201218_085604_PDX-X120RC02-A06006-V120691F_VIDEO_000197 (1).mp4"
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 217MB/s]
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/602) /content/MFK5_D025185_20201218_085604_PDX-X120RC02-A06006-V120691F_VIDEO_000197 (1).mp4: 384x640 (no detections), 79.5ms
# video 1/1 (frame 2/602) /content/MFK5_D025185_20201218_085604_PDX-X120RC02-A06006-V120691F_VIDEO_000197 (1).mp4: 384x640 (no detections), 25.4ms
# video 1/1 (frame 3/602) /content/MFK5_D025185_20201218_085604_PDX-X120RC02-A06006-V120691F_VIDEO_000197 (1).mp4: 384x640 1 truck, 25.3ms
# video 1/1 (frame 4/602) /content/MFK5_D025185_20201218_085604_PDX-X120RC02-A06006-V120691F_VIDEO_000197 (1).mp4: 384x640 1 truck, 25.4ms
# video 1/1 (frame 5/602) /content/MFK5_D025185_20201218_085604_PDX-X120RC02-A06006-V120691F_VIDEO_000197 (1).mp4: 384x640 1 truck, 25.3ms
# ...

# %%
# !ffmpeg -i {'/content/runs/detect/predict/mfk5.avi'} -vcodec libx264 {"video.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
